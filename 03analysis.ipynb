# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt

import pandas as pd
import numpy as np

# Read the data
df = pd.read_csv('./cleandata.csv')

#Change data types

# Map the data types for each column
dtypes_mapping = {
'ID'                                  : 'str',
'Age'                                 : 'object',
'Residence'                           : 'category',
'V-SE-Power'                          : 'int',
'V-SE-Achievement'                   : 'int',
'AVG-V-Self-Enhacemen'                : 'float',
'V-O-Hedonism'                         : 'int',
'V-O-Stimulation'                       : 'int',
'V-O-Self_direction'                    : 'int',
'AVG-V-Openness_to_change'            : 'float',
'V-ST-Universalism'                     : 'int',
'V-ST-Benevolence'                      : 'int',
'AVG-V-Self_transcendence'            : 'float',
'V-C-Tradition'                         : 'int',
'V-C-Conformity'                        : 'int',
'V-C-Security'                          : 'int',
'AVG-V-Conservation'                  : 'float',
'P-OX-Aesthetic_appreciation'            : 'int',
'P-OX-Inquisitiveness'                   : 'int',
'P-OX-Creativity'                        : 'int',                  
'P-OX-Unconventionality'                 : 'int',
'P-E-Liveliness'                        : 'int',
'AVG-P-Opennes_to_experience'           : 'int',
'P-E-Social_self-esteem'                : 'int',
'P-E-Social_boldness'                   : 'int',
'P-E-Sociability'                       : 'int',
'AVG-P-Extraversion'                  : 'float',
'P-HH-Modesty'                          : 'int',
'P-HH-Greed avoidance'                  : 'int',
'P-HH-Fairness'                         : 'int',
'P-HH-Sincerity'                        : 'int',
'AVG-P-Honesty-Humility'              : 'float',
'ATT-Favourable'                        : 'int',
'ATT-Smart'                             : 'int',
'AVG-ATT'                             : 'float',
'BEH-take_part'                         : 'int',
'BEH-passenger-usage'                 : 'int',
'PARTIC-YES-passenger-explanation'    : 'str',
'BEH-driver-usage'                    : 'int',
'PARTIC-YES-driver-explanation'        : 'str',
'INT-passenger'                       : 'int',
'INT-passenger-explanation'            : 'str',
'INT-driver'                         : 'int',
'INT-driver-explanation'               : 'str',
}

# Use astype to apply the data type changes
df = df.astype(dtypes_mapping)

print("\nData Types for Each Column:")
print(df.dtypes)

# %%
# Display basic statistics
print("Descriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#        V-SE-Power  V-SE-Achievement  AVG-V-Self-Enhacemen  V-O-Hedonism  \
# count  178.000000        178.000000            178.000000    178.000000
# mean     3.848315          5.196629              4.522472      5.353933
# std      1.848659          2.240004              1.705607      2.370609
# min      1.000000          1.000000              1.000000      1.000000
# 25%      2.000000          4.000000              3.500000      3.250000
# 50%      4.000000          5.000000              4.500000      5.000000
# 75%      5.000000          7.000000              5.500000      7.000000
# max      9.000000          9.000000              9.000000      9.000000
#
#        V-O-Stimulation  V-O-Self_direction  AVG-V-Openness_to_change  \
# count       178.000000          178.000000                178.000000
# mean          5.876404            7.466292                  6.232191
# std           2.342533            2.056130                  1.707610
# ...

# %%
import pandas as pd
from tabulate import tabulate

# Sample data
data = {'Age': ['25-34', '45-54', '35-44', '25-34', '65+', '55-64', '35-44', '55-64', '45-54', '18-24']}
df = pd.DataFrame(data)

# Sort the DataFrame by the "Age" column in ascending order
df.sort_values(by='Age', inplace=True)

# Calculate the frequency of values in the "Age" column
age_frequency = df['Age'].value_counts()

# Calculate the percentage of frequency
age_percentage = (age_frequency / len(df)) * 100

# Calculate the cumulative percentage
cumulative_percentage = age_percentage.cumsum()

# Create a DataFrame with Age, Frequency, Percentage, and Cumulative Percentage
age_summary_df = pd.DataFrame({'Age': age_frequency.index, 'Frequency': age_frequency.values, 'Percentage': age_percentage.values, 'Cumulative Percentage': cumulative_percentage.values})

# Print the results in tabular format
table = tabulate(age_summary_df, headers='keys', tablefmt='pretty', showindex=False)

# Print the table
print(table)
# Out:
# +-------+-----------+------------+-----------------------+
# |  Age  | Frequency | Percentage | Cumulative Percentage |
# +-------+-----------+------------+-----------------------+
# | 25-34 |     2     |    20.0    |         20.0          |
# | 35-44 |     2     |    20.0    |         40.0          |
# | 45-54 |     2     |    20.0    |         60.0          |
# | 55-64 |     2     |    20.0    |         80.0          |
# | 18-24 |     1     |    10.0    |         90.0          |
# |  65+  |     1     |    10.0    |         100.0         |
# +-------+-----------+------------+-----------------------+

# %%
# Calculate the frequency of values in the "Age" column
age_frequency = df['Age'].value_counts()

# Calculate the percentage of frequency
age_percentage = (age_frequency / len(df)) * 100

# Calculate the cumulative percentage
cumulative_percentage = age_percentage.cumsum()

# Create a DataFrame with Age, Frequency, Percentage, and Cumulative Percentage
age_summary_df = pd.DataFrame({'Age': age_frequency.index, 'Frequency': age_frequency.values, 'Percentage': age_percentage.values, 'Cumulative Percentage': cumulative_percentage.values})

# Print the results
print("Frequency, Percentage, and Cumulative Percentage of Age:")
print(age_summary_df)

# Save the cleaned DataFrame to cleandata.csv
age_summary_df.to_csv('age.csv', index=False)
print("\nDataFrame has been saved as age.csv")
# Out:
# Frequency, Percentage, and Cumulative Percentage of Age:
#      Age  Frequency  Percentage  Cumulative Percentage
# 0  25-34         91   51.123596              51.123596
# 1  35-44         46   25.842697              76.966292
# 2  45-54         17    9.550562              86.516854
# 3  18-24         14    7.865169              94.382022
# 4  55-64          8    4.494382              98.876404
# 5    65+          2    1.123596             100.000000
#
# DataFrame has been saved as age.csv

# %%
df_sorted = df.sort_values(by='Age')

# Plot the histogram
plt.figure(figsize=(10, 6))
plt.hist(df_sorted['Age'], bins=20, color='blue', edgecolor='black')
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %%
import pandas as pd
from scipy.stats import spearmanr
from tabulate import tabulate

# Assuming df is your DataFrame
selected_variables = ['Age', 'AVG-ATT', 'BEH-take_part', 'BEH-passenger-usage', 'BEH-driver-usage', 'INT-passenger', 'INT-driver']
df_selected = df[selected_variables]

# Convert 'Age' to a categorical data type with an ordinal order
age_categories = ['18-24', '25-34', '35-44', '45-54', '55-64', '65+']
df_selected['Age'] = pd.Categorical(df_selected['Age'], categories=age_categories, ordered=True)

# Calculate Spearman correlation matrix
correlation_matrix, p_values = spearmanr(df_selected, nan_policy='omit')

# Print the variable names, correlation coefficients, and p-values
for i, var1 in enumerate(selected_variables):
    for j, var2 in enumerate(selected_variables):
        if i < j:  # To avoid printing duplicate pairs
            print(f"{var1} - {var2}:")
            print(f"Spearman correlation coefficient: {correlation_matrix[i, j]:.2f}")
            print(f"P-value: {p_values[i, j]:.3f}")
            print()
# Out:
# Age - AVG-ATT:
# Spearman correlation coefficient: -0.08
# P-value: 0.268
#
# Age - BEH-take_part:
# Spearman correlation coefficient: -0.20
# P-value: 0.008
#
# Age - BEH-passenger-usage:
# Spearman correlation coefficient: -0.09
# P-value: 0.244
#
# Age - BEH-driver-usage:
# Spearman correlation coefficient: 0.03
# P-value: 0.655
#
# Age - INT-passenger:
# Spearman correlation coefficient: -0.20
# P-value: 0.007
#
# Age - INT-driver:
# Spearman correlation coefficient: -0.13
# P-value: 0.085
#
# AVG-ATT - BEH-take_part:
# Spearman correlation coefficient: 0.24
# P-value: 0.002
#
# AVG-ATT - BEH-passenger-usage:
# Spearman correlation coefficient: 0.25
# P-value: 0.001
#
# AVG-ATT - BEH-driver-usage:
# Spearman correlation coefficient: 0.16
# P-value: 0.036
#
# AVG-ATT - INT-passenger:
# Spearman correlation coefficient: 0.32
# P-value: 0.000
#
# AVG-ATT - INT-driver:
# Spearman correlation coefficient: 0.34
# P-value: 0.000
#
# BEH-take_part - BEH-passenger-usage:
# ...

# %%
import pandas as pd
from scipy.stats import kruskal

# Assuming df is your DataFrame with 'Residence' and other numerical variables
selected_residences = ['Slovenia', 'Germany', 'Finland']
df_selected_residences = df[df['Residence'].isin(selected_residences)]

# Numerical variables for analysis
numerical_variables = ['AVG-ATT', 'BEH-take_part', 'BEH-passenger-usage', 'BEH-driver-usage', 'INT-passenger', 'INT-driver']

# Perform the Kruskal-Wallis test for each variable
for variable in numerical_variables:
    print(f"Kruskal-Wallis test for {variable} among selected residences:\n")

    # Extract data for each residence
    data_slovenia = df_selected_residences[df_selected_residences['Residence'] == 'Slovenia'][variable]
    data_germany = df_selected_residences[df_selected_residences['Residence'] == 'Germany'][variable]
    data_finland = df_selected_residences[df_selected_residences['Residence'] == 'Finland'][variable]

    # Perform Kruskal-Wallis test
    stat, p_value = kruskal(data_slovenia, data_germany, data_finland)
    
    print(f"Kruskal-Wallis statistic: {stat:.2f}")
    print(f"P-value: {p_value:.3f}\n")
# Out:
# Kruskal-Wallis test for AVG-ATT among selected residences:
#
# Kruskal-Wallis statistic: 0.37
# P-value: 0.831
#
# Kruskal-Wallis test for BEH-take_part among selected residences:
#
# Kruskal-Wallis statistic: 0.62
# P-value: 0.734
#
# Kruskal-Wallis test for BEH-passenger-usage among selected residences:
#
# Kruskal-Wallis statistic: 1.85
# P-value: 0.397
#
# Kruskal-Wallis test for BEH-driver-usage among selected residences:
#
# Kruskal-Wallis statistic: 15.63
# P-value: 0.000
#
# Kruskal-Wallis test for INT-passenger among selected residences:
#
# Kruskal-Wallis statistic: 0.79
# P-value: 0.674
#
# Kruskal-Wallis test for INT-driver among selected residences:
#
# Kruskal-Wallis statistic: 0.08
# P-value: 0.961

# %%
import pandas as pd
from scipy.stats import f_oneway

# Assuming df is your DataFrame with 'Residence' and other numerical variables
selected_residences = ['Slovenia', 'Germany', 'Finland']
df_selected_residences = df[df['Residence'].isin(selected_residences)]

# Numerical variables for analysis
numerical_variables = ['AVG-ATT', 'BEH-take_part', 'BEH-passenger-usage', 'BEH-driver-usage', 'INT-passenger', 'INT-driver']

# Perform the ANOVA test for each variable
for variable in numerical_variables:
    print(f"ANOVA test for {variable} among selected residences:\n")

    # Extract data for each residence
    data_slovenia = df_selected_residences[df_selected_residences['Residence'] == 'Slovenia'][variable]
    data_germany = df_selected_residences[df_selected_residences['Residence'] == 'Germany'][variable]
    data_finland = df_selected_residences[df_selected_residences['Residence'] == 'Finland'][variable]

    # Perform ANOVA test
    stat, p_value = f_oneway(data_slovenia, data_germany, data_finland)
    
    print(f"F-statistic: {stat:.2f}")
    print(f"P-value: {p_value:.3f}\n")
# Out:
# ANOVA test for AVG-ATT among selected residences:
#
# F-statistic: 0.32
# P-value: 0.723
#
# ANOVA test for BEH-take_part among selected residences:
#
# F-statistic: 0.31
# P-value: 0.736
#
# ANOVA test for BEH-passenger-usage among selected residences:
#
# F-statistic: 1.59
# P-value: 0.207
#
# ANOVA test for BEH-driver-usage among selected residences:
#
# F-statistic: 5.87
# P-value: 0.004
#
# ANOVA test for INT-passenger among selected residences:
#
# F-statistic: 0.48
# P-value: 0.617
#
# ANOVA test for INT-driver among selected residences:
#
# F-statistic: 0.02
# P-value: 0.979

# %%
# Calculate the frequency of values in the "Residency" column
residence_frequency = df['Residence'].value_counts()

# Calculate the percentage of frequency
residence_percentage = (residence_frequency / len(df)) * 100

# Calculate the cumulative percentage
cumulative_percentage = residence_percentage.cumsum()

# Create a DataFrame with Age, Frequency, Percentage, and Cumulative Percentage
residence_summary_df = pd.DataFrame({'Residence': residence_frequency.index, 'Frequency': residence_frequency.values, 'Percentage': residence_percentage.values, 'Cumulative Percentage': cumulative_percentage.values})

# Print the results
#print("Frequency, Percentage, and Cumulative Percentage of Residence:")
#print(residence_summary_df)

# Print the results in tabular format
tabler = tabulate(residence_summary_df, headers='keys', tablefmt='pretty', showindex=False)

# Print the table
print(tabler)
# Out:
# +------------------------------------------------------+-----------+--------------------+-----------------------+
# |                      Residence                       | Frequency |     Percentage     | Cumulative Percentage |
# +------------------------------------------------------+-----------+--------------------+-----------------------+
# |                       Slovenia                       |    63     | 35.39325842696629  |   35.39325842696629   |
# |                       Germany                        |    58     | 32.58426966292135  |   67.97752808988764   |
# |                       Finland                        |    18     | 10.112359550561797 |   78.08988764044943   |
# |                       Croatia                        |     8     |  4.49438202247191  |   82.58426966292134   |
# |                     Netherlands                      |     4     | 2.247191011235955  |   84.8314606741573    |
# ...

# %%
# Calculate the frequency of values in the "Residency" column
residence_frequency = df_sorted['Residence'].value_counts()

# Sort the values in descending order
residence_frequency = residence_frequency.sort_values(ascending=False)

# Plot the histogram
plt.figure(figsize=(30, 10))
plt.bar(residence_frequency.index, residence_frequency.values, color='blue', edgecolor='black')
plt.title('Distribution of Residence')
plt.xlabel('Residence')
plt.ylabel('Frequency')
plt.xticks(rotation='vertical')  # Rotate x-axis labels vertically
plt.grid(True)
plt.show()

# %%
selected_columns = ['Age', 
                    'Residence', 
                    'AVG-V-Self-Enhacemen',
                    'AVG-V-Openness_to_change', 
                    'AVG-V-Self_transcendence', 
                    'AVG-V-Conservation',
                    'AVG-P-Extraversion',
                    'AVG-P-Honesty-Humility',
                    'AVG-ATT',
                    'BEH-take_part',
                    'INT-passenger',
                    'INT-driver' ]

selected_df = df[selected_columns]

correlation_matrix = selected_df.corr()

# Display the correlation matrix
print("Correlation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                           AVG-V-Self-Enhacemen  AVG-V-Openness_to_change  \
# AVG-V-Self-Enhacemen                  1.000000                  0.288772
# AVG-V-Openness_to_change              0.288772                  1.000000
# AVG-V-Self_transcendence              0.090270                  0.371308
# AVG-V-Conservation                    0.162263                  0.126516
# AVG-P-Extraversion                    0.198271                  0.033338
# AVG-P-Honesty-Humility               -0.236852                  0.000797
# AVG-ATT                              -0.031729                  0.044919
# BEH-take_part                        -0.041962                  0.004734
# INT-passenger                         0.049197                  0.146707
# INT-driver                           -0.043181                 -0.027141
#
#                           AVG-V-Self_transcendence  AVG-V-Conservation  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plotting a heatmap
sns.heatmap(correlation_matrix, cmap='coolwarm', annot=True, fmt=".2f", linewidths=.5)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# Assuming df is your DataFrame
correlation_matrix = df.corr()

# Create a matrix to store p-values
p_values = np.zeros_like(correlation_matrix)

# Calculate correlation coefficients and p-values
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr, p_value = pearsonr(df[correlation_matrix.columns[i]], df[correlation_matrix.columns[j]])
        correlation_matrix.iloc[i, j] = corr
        p_values[i, j] = p_value

# Print only significant correlations
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        if p_values[i, j] < 0.05:  # Adjust significance level as needed
            print(f"{correlation_matrix.columns[i]} - {correlation_matrix.columns[j]}: "
                  f"{correlation_matrix.iloc[i, j]:.2f} (p-value: {p_values[i, j]:.3f})")
# Out:
# /var/folders/s6/d9drx76x0952zv9k4v36kftw0000gp/T/ipykernel_16269/474748527.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
# V-SE-Power - V-SE-Achievement: 0.39 (p-value: 0.000)
# V-SE-Power - AVG-V-Self-Enhacemen: 0.80 (p-value: 0.000)
# V-SE-Power - V-O-Hedonism: 0.16 (p-value: 0.032)
# V-SE-Power - V-O-Stimulation: 0.25 (p-value: 0.001)
# V-SE-Power - AVG-V-Openness_to_change: 0.20 (p-value: 0.008)
# V-SE-Power - P-E-Sociability: 0.23 (p-value: 0.002)
# V-SE-Power - P-HH-Greed avoidance: -0.34 (p-value: 0.000)
# V-SE-Power - P-HH-Fairness: -0.17 (p-value: 0.022)
# V-SE-Power - AVG-P-Honesty-Humility: -0.21 (p-value: 0.005)
# V-SE-Achievement - AVG-V-Self-Enhacemen: 0.87 (p-value: 0.000)
# V-SE-Achievement - V-O-Hedonism: 0.20 (p-value: 0.008)
# ...

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# Assuming df is your DataFrame
selected_variables = ['AVG-V-Self-Enhacemen', 'AVG-V-Openness_to_change', 'AVG-V-Self_transcendence',
                       'AVG-V-Conservation', 'AVG-P-Extraversion', 'AVG-P-Honesty-Humility', 'AVG-ATT',
                       'BEH-take_part', 'BEH-passenger-usage', 'BEH-driver-usage', 'INT-passenger', 'INT-driver']

# Select only the specified variables from the DataFrame
df_selected = df[selected_variables]

# Calculate the correlation matrix for the selected variables
correlation_matrix = df_selected.corr()

# Create a matrix to store p-values
p_values = np.zeros_like(correlation_matrix)

# Calculate correlation coefficients and p-values
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        corr, p_value = pearsonr(df_selected[correlation_matrix.columns[i]], df_selected[correlation_matrix.columns[j]])
        correlation_matrix.iloc[i, j] = corr
        p_values[i, j] = p_value

# Print only significant correlations
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        if p_values[i, j] < 0.05:  # Adjust significance level as needed
            print(f"{correlation_matrix.columns[i]} - {correlation_matrix.columns[j]}: "
                  f"{correlation_matrix.iloc[i, j]:.2f} (p-value: {p_values[i, j]:.3f})")
# Out:
# AVG-V-Self-Enhacemen - AVG-V-Openness_to_change: 0.29 (p-value: 0.000)
# AVG-V-Self-Enhacemen - AVG-V-Conservation: 0.16 (p-value: 0.030)
# AVG-V-Self-Enhacemen - AVG-P-Honesty-Humility: -0.24 (p-value: 0.001)
# AVG-V-Openness_to_change - AVG-V-Self_transcendence: 0.37 (p-value: 0.000)
# AVG-V-Openness_to_change - AVG-P-Extraversion: 0.25 (p-value: 0.001)
# AVG-V-Self_transcendence - AVG-V-Conservation: 0.18 (p-value: 0.014)
# AVG-V-Self_transcendence - AVG-P-Extraversion: 0.31 (p-value: 0.000)
# AVG-V-Self_transcendence - AVG-P-Honesty-Humility: 0.16 (p-value: 0.038)
# AVG-V-Self_transcendence - AVG-ATT: 0.26 (p-value: 0.001)
# AVG-V-Self_transcendence - INT-passenger: 0.22 (p-value: 0.003)
# AVG-P-Extraversion - AVG-ATT: 0.17 (p-value: 0.021)
# AVG-P-Extraversion - INT-driver: 0.15 (p-value: 0.040)
# AVG-ATT - BEH-take_part: 0.21 (p-value: 0.006)
# AVG-ATT - BEH-passenger-usage: 0.21 (p-value: 0.004)
# AVG-ATT - INT-passenger: 0.33 (p-value: 0.000)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# Assuming df is your DataFrame
selected_variables = ['AVG-V-Self-Enhacemen', 'AVG-V-Openness_to_change', 'AVG-V-Self_transcendence',
                       'AVG-V-Conservation', 'AVG-P-Extraversion', 'AVG-P-Honesty-Humility', 'AVG-ATT',
                       'BEH-take_part', 'BEH-passenger-usage', 'BEH-driver-usage', 'INT-passenger', 'INT-driver']

# Select only the specified variables from the DataFrame
df_selected = df[selected_variables]

# Calculate the correlation matrix for the selected variables
correlation_matrix = df_selected.corr()

# Create a matrix to store p-values
p_values = np.zeros_like(correlation_matrix)

# Calculate correlation coefficients and p-values
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        corr, p_value = pearsonr(df_selected[correlation_matrix.columns[i]], df_selected[correlation_matrix.columns[j]])
        correlation_matrix.iloc[i, j] = corr
        p_values[i, j] = p_value

# Create a mask for significant correlations
mask = np.triu(np.ones_like(correlation_matrix, dtype=bool), k=1)  # Upper triangle mask

# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(10, 8))

# Draw the heatmap with significant correlations
cax = sns.heatmap(correlation_matrix, mask=mask, cmap='coolwarm', vmin=-1, vmax=1, annot=True, fmt=".2f", cbar_kws={"shrink": 0.8})

# Add significance labels
for i in range(len(correlation_matrix.columns)):
    for j in range(i + 1, len(correlation_matrix.columns)):
        if p_values[i, j] < 0.05:  # Adjust significance level as needed
            significance = "*"
        elif p_values[i, j] < 0.01:
            significance = "**"
        elif p_values[i, j] < 0.001:
            significance = "***"
        else:
            significance = ""  # No significance label if p-value is not significant

        ax.text(j + 0.5, i + 0.5, significance, ha='center', va='center', color='black', fontsize=12)

# Set axis labels
plt.xticks(range(len(correlation_matrix.columns)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix.columns)), correlation_matrix.columns)

plt.title('Correlation Matrix for Selected Variables with Significance Labels')
plt.show()

# %%
import pandas as pd
import numpy as np
from scipy.stats import pearsonr
from tabulate import tabulate

# Assuming df is your DataFrame
correlation_matrix = df.corr()

# Create a matrix to store p-values
p_values = np.zeros_like(correlation_matrix)

# Calculate correlation coefficients and p-values
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr, p_value = pearsonr(df[correlation_matrix.columns[i]], df[correlation_matrix.columns[j]])
        correlation_matrix.iloc[i, j] = corr
        p_values[i, j] = p_value

# Create a DataFrame for p-values
p_values_df = pd.DataFrame(p_values, index=correlation_matrix.columns, columns=correlation_matrix.columns)

# Create a table with correlation coefficients and p-values
table_data = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        correlation_coefficient = correlation_matrix.iloc[i, j]
        p_value = p_values_df.iloc[i, j]
        significance = ""
        
        if p_value < 0.05:
            significance = "*"
        if p_value < 0.01:
            significance = "**"
        if p_value < 0.001:
            significance = "***"

        table_data.append([correlation_matrix.columns[i], correlation_matrix.columns[j],
                           correlation_coefficient, p_value, significance])

# Print the table
headers = ["Variable 1", "Variable 2", "Correlation Coefficient", "P-Value", "Significance"]
table = tabulate(table_data, headers=headers, floatfmt=(".2f", ".2f", ".3f", ".3f", ""), tablefmt="pretty")
print(table)
# Out:
# /var/folders/s6/d9drx76x0952zv9k4v36kftw0000gp/T/ipykernel_16269/2557768993.py:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
# +----------------------------+----------------------------+-------------------------+------------------------+--------------+
# |         Variable 1         |         Variable 2         | Correlation Coefficient |        P-Value         | Significance |
# +----------------------------+----------------------------+-------------------------+------------------------+--------------+
# |         V-SE-Power         |      V-SE-Achievement      |   0.38652858569887877   | 9.864816198714398e-08  |     ***      |
# |         V-SE-Power         |    AVG-V-Self-Enhacemen    |   0.7957529360234548    | 3.497827545308359e-40  |     ***      |
# ...

# %%
import pandas as pd

# Sample data
catdata = {
    'Age': ['25-34', '45-54', '35-44', '25-34', '65+', '55-64', '35-44', '55-64', '45-54', '18-24'],
    'Residence': ['Urban', 'Suburban', 'Urban', 'Rural', 'Suburban', 'Urban', 'Rural', 'Urban', 'Suburban', 'Urban']
}

# Create a DataFrame
df = pd.DataFrame(catdata)

# Display counts for each category
age_counts = df['Age'].value_counts()
residence_counts = df['Residence'].value_counts()

# Display percentages for each category
age_percentages = df['Age'].value_counts(normalize=True) * 100
residence_percentages = df['Residence'].value_counts(normalize=True) * 100

# Combine counts and percentages into a summary DataFrame
summary_df = pd.DataFrame({
    'Age Counts': age_counts,
    'Age Percentages': age_percentages,
    'Residence Counts': residence_counts,
    'Residence Percentages': residence_percentages
})

# Display the summary
print(summary_df)
# Out:
#           Age Counts  Age Percentages  Residence Counts  Residence Percentages
# 18-24            1.0             10.0               NaN                    NaN
# 25-34            2.0             20.0               NaN                    NaN
# 35-44            2.0             20.0               NaN                    NaN
# 45-54            2.0             20.0               NaN                    NaN
# 55-64            2.0             20.0               NaN                    NaN
# 65+              1.0             10.0               NaN                    NaN
# Rural            NaN              NaN               2.0                   20.0
# Suburban         NaN              NaN               3.0                   30.0
# Urban            NaN              NaN               5.0                   50.0
